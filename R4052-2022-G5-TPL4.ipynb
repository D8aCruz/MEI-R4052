# %% [markdown]
# <img src="logo-utn-frba-electronica-green.png" style="float: right;" width="200" height="40" alt="InternetCtrl">
# <p style=" font-family: Courier New,Courier,Lucida Sans Typewriter,Lucida Typewriter,monospace; text-align: left;"><font color='black'>MEDIDAS ELECTRÓNICAS I<br>Curso R4052</font></p>

# %% [markdown]
# <p style="border: ridge black 2px; text-align: center;font-weight: italic; font-size:25px; background-color:#0EEA0B">
#     Trabajo Práctico N° 4
# </p>

# %% [markdown]
# <p style="text-align: center; font-weight: italic; font-size:15px;">Osciloscopia Digital (DSO)</p>
# <hr style="border: ridge #0EEA0B 1px;">

# %% [markdown]
# <table style="border-collapse:collapse;border-spacing:0;
#               border-color:black;border-style:solid;border-width:1px;
#               font-family:Arial,sans-serif;font-size:14px;
#               overflow:hidden;padding:10px 5px;word-break:normal;
#               border-color:black;border-style:solid;border-width:1px;
#               font-family:Arial, sans-serif;font-size:14px;
#               font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;
#               border-color:inherit;text-align:left;vertical-align:top">
# <thead>
#   <tr>
#     <th style="border-color:black;border-style:solid;border-width:1px;
#               ont-family:Arial, sans-serif;font-size:14px;
#               font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;"> </th>
#     <th style="border-color:black;border-style:solid;border-width:1px;
#               font-family:Arial, sans-serif;font-size:14px;
#               font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;
#               border-color:inherit;text-align:left;vertical-align:top"> <strong>   INTEGRANTES    </strong></th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">1</td>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">    David ochoa Cruz    </td>
#   </tr>
#   <tr>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">1</td>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">   Paulo Andres Lopez Velandia   </td>
#   </tr>
#   <tr>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">2</td>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">    Christian Georg KÖnig    </td>
#   </tr>
#   <tr>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">3</td>
#     <td style="border-color:black;border-style:solid;border-width:1px;
#                font-family:Arial, sans-serif;font-size:14px;
#                overflow:hidden;padding:10px 5px;word-break:normal;
#                border-color:inherit;text-align:left;vertical-align:top">    José Martín Sosa    </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <hr style="border: ridge #0EEA0B 1px;">
# <br>
# <p style="border: ridge #0EEA0B 2px; text-align: left;font-weight: italic; font-size:15px;">
#     Objetivos
# </p>

# %% [markdown]
# <ol style="background-size: 3.2em;">
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Medición de Impedancia</strong>
#         <p style="text-align: justify;">
#             Se busca medir la impedancia de un dipolo paralelo conformado por un
#             capacitor y una resistencia cuya fase se encuentra entre 25º/40º a una
#             frecuencia de 1kHz. Para ello se propone medir la tensión y corriente del
#             dipolo utilizando un DSO y un resistencia en serie para medir la corriente.
#             Nota: Tenga cuidado de definir las resistencias para que las mediciones de
#             tensión esté en la misma escala y de no cortocircuitar las masas del DSO.</p>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Mediciones de eventos únicos</strong>
#         <p style="text-align: justify;">
#             Utilizando un circuito conformado por un relé,
#             un switch y un diodo removible se busca medir:</p>
#         <ul>
#           <li>Tiempo de apertura y tiempo de cierre
#               (con y sin diodo de protección)</li>
#           <li>Sobre-tensión en la llave en el momento de
#               apertura (con y sin diodo de protección)</li>
#         </ul>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Tiempo de establecimiento</strong>
#         <p style="text-align: justify;">
#             Medir el tiempo de establecimiento de un generador de señal rectangular.</p>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Compensación de la punta</strong>
#         <p style="text-align: justify;">
#             A partir de una señal senoidal de 100 kHz y Vpp = 4 V, medir el máximo error
#             de tensión que se puede producir utilizando una punta sin compensar frente a otra compensada. </p>
#     </li>
# </ol>

# %% [markdown]
# <hr style="border: ridge #0EEA0B 1px;">
# <br>
# <p style="border: ridge #0EEA0B 2px; text-align: left;font-weight: italic; font-size:15px;">
#     Instrumental y materiales
# </p>

# %% [markdown]
# <ul style="background-size: 3.2em;">
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Alumnos:</strong>
#         <ul>
#           <li>Resistencias Varias</li>
#           <li>Capacitor Varios</li>
#           <li>Rele 12V</li>
#           <li>Protoboard </li>
#         </ul>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Alumnos:</strong>
#         <ul>
#           <li>Resistencias Varias</li>
#           <li>Capacitor Varios</li>
#           <li>Rele 12V</li>
#           <li>Protoboard </li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <hr style="border: ridge #0EEA0B 1px;">
# <br>
# <p style="border: ridge #0EEA0B 2px; text-align: left;font-weight: italic; font-size:15px;">
#     Documentación a entregar
# </p>

# %% [markdown]
# <p>Para la aprobación del trabajo práctico se deberá entregar la siguiente documentación adicional separada en secciones o documentos.</p>
#
# <ol style="background-size: 3.2em;">
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Carátula</strong>
#         <p style="text-align: justify;">
#             Título, Integrantes, Nº de Grupo, Curso, etc.</p>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Procedimiento específico de la
#                 medición</strong>
#         <p style="text-align: justify;">
#             Debe contener la información necesaria para reproducir la medición y el respaldo retórico que hacen válida la medición. Ej: Instrumental, ecuaciones teóricas, pasos para tomar la medición, circuito de conexión, etc.</p>
#     </li>
#     <li style="position: relative;
#                margin-bottom: 1.5em;
#                padding: 1.5em;
#                background-color: #E3FFE3;">
#         <strong>Resultado de la medición</strong>
#         <p style="text-align: justify;">
#             Debe contener solo los resultados de la medición con su incertidumbre y las condiciones de contorno asociadas a ella. </p>
#     </li>
#     <li style="position: relative;
#            margin-bottom: 1.5em;
#            padding: 1.5em;
#            background-color: #E3FFE3;">
#     <strong>Hoja de cálculos de las incertidumbre</strong>
#     <p style="text-align: justify;">
#        Debe contener en manera digital las ecuaciones y todos los cálculos necesarios para obtener las incertidumbres.</p>
#     </li>
#     <li style="position: relative;
#            margin-bottom: 1.5em;
#            padding: 1.5em;
#            background-color: #E3FFE3;">
#     <strong>Conclusiones</strong>
#     <p style="text-align: justify;">
#        Ubique todas las conclusiones de la medición u otra observación pertinente que obtenga de la realización de la práctica..</p>
#     </li>
# </ol>

# %% [markdown]
# <div align="right">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" width="200" height="40">
# </div>
#
# # MEDIDAS ELECTRÓNICAS I
# ## Curso R4052

# %% [markdown]
# <div style="display: flex; align-items: center;">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" width="200" height="40" style="flex-shrink: 0;">
#   <p style="font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace; text-align: right; margin-right: 10px;">
#     <font color='black'><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052<br>David Ochoa Cruz</font>
#   </p>
# </div>

# %% [markdown]
# <div style="display: flex; align-items: center;">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" width="200" height="40" style="flex-shrink: 0;">
#   <p style="font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace; text-align: left; margin-left: 10px;">
#     <font color='black'><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052</font>
#   </p>
# </div>

# %% [markdown]
# <img src="logo-utn-frba-electronica-green.png" style="float: right;" width="200" height="40" alt="InternetCtrl">
# <p style=" font-family: Courier New,Courier,Lucida Sans Typewriter,Lucida Typewriter,monospace; text-align: left;"><font color='white'>MEDIDAS ELECTRÓNICAS I<br>Curso R4052</font></p>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   /* Tus estilos CSS aquí */
#   body {
#     font-family: Arial, sans-serif;
#   }
#   .container {
#     text-align: center;
#     margin: 20px;
#   }
#   .my-image {
#     width: 200px;
#     height: auto;
#     border: 2px solid #ccc;
#     border-radius: 5px;
#   }
# </style>
# </head>
# <body>
# <div class="container">
#   <img src="logo-utn-frba-electronica-green.png" alt="Mi Imagen" class="my-image">
#   <p>Mi descripción aquí</p>
# </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   /* Tus estilos CSS aquí */
#   body {
#     font-family: Arial, sans-serif;
#     background-color: #f0f0f0;
#   }
#   .container {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     text-align: left;
#     margin: 20px;
#     padding: 10px;
#     background-color: #ffffff;
#     color: #000000;
#     border: 2px solid #ccc;
#     border-radius: 5px;
#   }
#   .my-image {
#     width: 200px;
#     height: auto;
#   }
#   .text {
#     font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace;
#     text-align: left;
#     margin-left: 10px;
#     color: black;
#   }
# </style>
# </head>
# <body>
# <div class="container">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" class="my-image">
#   <div class="text">
#     <p><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052</p>
#   </div>
# </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   /* Tus estilos CSS aquí */
#   body {
#     font-family: Arial, sans-serif;
#     background-color: #f0f0f0;
#   }
#   .container {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     text-align: left;
#     margin: 20px;
#     padding: 10px;
#     background-color: #ffffff;
#     color: #000000;
#     border: 2px solid #ccc;
#     border-radius: 5px;
#   }
#   .my-image {
#     width: 200px;
#     height: auto;
#     order: 2;
#   }
#   .text {
#     font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace;
#     text-align: right;
#     margin-right: 10px;
#     color: black;
#     order: 1;
#   }
# </style>
# </head>
# <body>
# <div class="container">
#   <div class="text">
#     <p><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052</p>
#   </div>
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" class="my-image">
# </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
# <style>
#   /* Tus estilos CSS aquí */
#   body {
#     font-family: Arial, sans-serif;
#     background-color: white;
#   }
#   .container {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     text-align: left;
#     margin: 20px;
#     padding: 10px;
#     color: white;
#   }
#   .my-image {
#     width: 100px;
#     height: auto;
#     order: 2;
#   }
#   .text {
#     font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace;
#     text-align: left;
#     margin-right: 10px;
#     order: 1;
#   }
# </style>
# </head>
# <body>
# <div class="container">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" class="my-image">
#   <div class="text">
#     <p><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052<br>David Ochoa Cruz</p>
#   </div>
# </div>
# </body>
# </html>

# %% [markdown]
# <div style="display: flex; align-items: center;">
#   <img src="logo-utn-frba-electronica-green.png" alt="Logo UTN FRBA" width="200" height="40" style="flex-shrink: 0;">
#   <p style="font-family: 'Courier New', Courier, 'Lucida Sans Typewriter', 'Lucida Typewriter', monospace; text-align: right; margin-left: auto;">
#     <font color='black'><strong>MEDIDAS ELECTRÓNICAS I</strong><br>Curso R4052<br>David Ochoa Cruz</font>
#   </p>
# </div>
